# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#importing dataset
path = '/content/drive/MyDrive/Data Science Projects/Classification/K Means/Mall_Customers.csv'
df= pd.read_csv(path)
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 245         246    Male   30                 297                      69
# 246         247  Female   56                 311                      14
# 247         248    Male   29                 313                      90
# 248         249  Female   19                 316                      32
# 249         250  Female   31                 325                      86
#
# [250 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
X= df[['Annual Income (k$)','Spending Score (1-100)' ]].values.copy()
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans
wcss_list = []

for i in range(1, 11):
  kmeans= KMeans(n_clusters= i, init='k-means++', random_state=42, n_init=i)
  kmeans.fit(X)
  wcss_list.append(kmeans.inertia_)

plt.plot(range(1,11), wcss_list)
plt.title('Elbow Method')
plt.Xlabel('Number of clusters (k)')
plt.ylabel('wcss_list')
plt.show()

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42, n_init=10)
clusters = kmeans.fit_predict(X)

# %%
plt.scatter(X[clusters == 0, 0], X[clusters == 0, 1], s = 100, c = 'blue', label = 'Cluster 1') #for first cluster  
plt.scatter(X[clusters == 1, 0], X[clusters == 1, 1], s = 100, c = 'green', label = 'Cluster 2') #for second cluster
plt.scatter(X[clusters == 2, 0], X[clusters == 2, 1], s = 100, c = 'red', label = 'Cluster 3') #for third cluster  
plt.scatter(X[clusters == 3, 0], X[clusters == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') #for fourth cluster 
plt.scatter(X[clusters == 3, 0], X[clusters == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') 
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroid')  
plt.title('Clusters of customers')  
plt.xlabel('Annual Income (k$)')  
plt.ylabel('Spending Score (1-100)')  
plt.legend()  
plt.show()
